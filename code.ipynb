# %%
import pandas as pd

# %%
wines = pd.read_excel("data/Subset1.xls", 1)
# Out:
#       Table.No.               Cultivar  Color                 Recommend  \
# 0             9               Chardony  White  Particularly recommended
# 1             9               Chardony  White  Particularly recommended
# 2             9               Chardony  White  Particularly recommended
# 3             9               Chardony  White  Particularly recommended
# 4             9               Chardony  White  Particularly recommended
# ...         ...                    ...    ...                       ...
# 1478         25  Red Malaga (Molinera)    Red               Table grape
# 1479         25  Red Malaga (Molinera)    Red               Table grape
# 1480         25                 Ribier    Red               Table grape
# 1481         25                 Ribier    Red               Table grape
# 1482         25                 Ribier    Red               Table grape
#
#       RecReg  Reg Harvest date    DOY  Must.Brix  Must.Tacid  Must.pH  \
# ...

# %%
weather = pd.read_excel("data/Subset3.xls", [1,2,3,4,5])

# %%
weather[1]
# Out:
#        Year  Month  day   Tave  Tmax  Tmin  DOY  Unnamed: 7  Year.1  \
# 0      1911      1    1   8.35  16.7   0.0    1         NaN  1911.0
# 1      1911      1    2   8.85  19.4  -1.7    2         NaN  1912.0
# 2      1911      1    3   6.65  16.1  -2.8    3         NaN  1913.0
# 3      1911      1    4   8.30  18.3  -1.7    4         NaN  1914.0
# 4      1911      1    5   7.80  18.9  -3.3    5         NaN  1915.0
# ...     ...    ...  ...    ...   ...   ...  ...         ...     ...
# 36885  2011     12   27   6.95  15.6  -1.7  361         NaN     NaN
# 36886  2011     12   28  11.65  19.4   3.9  362         NaN     NaN
# 36887  2011     12   29  11.15  16.7   5.6  363         NaN     NaN
# 36888  2011     12   30  12.20  15.0   9.4  364         NaN     NaN
# 36889  2011     12   31   8.30  17.2  -0.6  365         NaN     NaN
#
#              GST           WI           HI
# 0      15.073364  1099.050000   967.254052
# 1      15.752336  1246.550000  1146.450272
# ...
